# %%
import pandas as pd

# %%
import sys
sys.executable
# Out:
# 'c:\\Users\\pek43\\AppData\\Local\\Programs\\Python\\Python314\\python.exe'

# %%
name = "My name is Patricia Klein and I am a Learning & Development Professional with over 20 years of experience."
